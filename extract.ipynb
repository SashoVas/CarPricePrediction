# %%
import pandas as pd
import numpy as np
import requests
import re

# %%
URL='https://www.mobile.bg/obiavi/avtomobili-dzhipove'

# %%
div_regex=re.compile('<div')
div_close_regex=re.compile('</div>')
span_regex=re.compile('<span>.*?</span>')
div_class_info_regex=re.compile('<div class="info">\n.*?\n</div>')
div_price_regex=re.compile('<div>[0-9 ]+ лв.</div>')
div_model_regex=re.compile('<a href=\".*?\" class="title saveSlink">.*?</a>')
div_location_regex=re.compile('<div class="location">.*?</div>')
href_regex=re.compile('www.mobile.bg/obiava.*?"')
mp_label_regex=re.compile('<div class="mpLabel">.*?</div>')
mp_info_regex=re.compile('<div class="mpInfo">.*?</div>')
div_start_plus_end_regex=re.compile('<div>.*?</div>')
div_remover_regex=re.compile('</{0,1}(div|span|a).*?>')
span_title_regex=re.compile('<span class="Title">.*?</span>')
item_div_regex=re.compile('<div.*?>.+')

# %%
def extract_divs(text,searched_div):
    line_parsing=False
    result=''
    results=[]
    count=0
    for line in text.split('\n'):
        line=line.strip()
        #print(line,count)
        if line_parsing:
            if div_regex.search(line):
                count+=1
            if div_close_regex.search(line):
                count-=1

            result+=f"{line}\n"
            if count==0:
                line_parsing=False
                results.append(result)
                result=''

        else:
            if not line.startswith(searched_div) :
                continue

            line_parsing=True
            result+=f"{line}\n"
            count=1
    return results

# %%
def first(a):
    return '' if len(a)==0 else a[0]

# %%
def get_info_of_cars_on_page(r):
    cars_top=extract_divs(r.text,'<div class="item TOP " id="')
    cars_default=extract_divs(r.text,'<div class="item  " id="')
    cars_short=extract_divs(r.text,'<div id="shortList6"')
    cars=cars_top+cars_default+cars_short
    cars_params=[]
    cars_info=[]
    cars_prices=[]
    cars_models=[]
    individual_urls=[]
    locations=[]
    status=['TOP']*len(cars_top)+['Default']*len(cars_default)+['SHORT']*len(cars_short)
    for car in cars:
        cars_params.append(span_regex.findall(car))
        cars_info.append(first(div_class_info_regex.findall(car)))
        cars_prices.append(first(div_price_regex.findall(car)))
        cars_models.append(first(div_model_regex.findall(car)))
        locations.append(first(div_location_regex.findall(car)))

    for car_model in cars_models:
        individual_urls.append(href_regex.findall(car_model)[0][:-1])

    individual_urls
    return (cars_models,cars_info,cars_prices,cars_params,individual_urls,locations,status)

# %%
def get_individual_car_cards_info(car_url):
    individual=requests.get(f'https://{car_url}')
    individual.encoding = individual.apparent_encoding

    info_html=extract_divs(individual.text,'<div class="borderBox carParams">')[0]
    info_labels=mp_label_regex.findall(info_html)
    infos_details=mp_info_regex.findall(info_html)

    tech_html=extract_divs(individual.text,'<div class="techData">')[0]
    data=div_start_plus_end_regex.findall(tech_html)
    tech_labels=data[0::2]
    tech_details=data[1::2]

    additional=first(extract_divs(individual.text,'<div class="carExtri">'))
    titles=span_title_regex.findall(additional)
    items_htmls=extract_divs(div_close_regex.sub('\n</div>\n',div_regex.sub('\n<div',additional)),'<div class="items">')
    items=[]
    for item in items_htmls:
        items.append(item_div_regex.findall(item))
    return (info_labels,infos_details,tech_labels,tech_details,titles,items)

# %%
def clean_nested(source):
    source_patched=[]
    for nested1_source in source:
        nested1_source_patched=[]
        for nested2 in nested1_source:
            nested1_source_patched.append(div_remover_regex.sub('',nested2).strip())
        source_patched.append(nested1_source_patched)   
    return source_patched

# %%
def data_cleaner(func):
    def clean_cars_data(page_url):
        cars_models,cars_description,cars_prices,cars_params,individual_urls,infos_labels,infos_details,tech_labels,tech_details,locations,all_titles,all_items,status=func(page_url)
        cars_models_patched=[div_remover_regex.sub('',i).strip() for i in cars_models]
        cars_description_patched=[div_remover_regex.sub('',i).strip() for i in cars_description]
        cars_prices_patched=[div_remover_regex.sub('',i).strip() for i in cars_prices]
        locations_patched=[div_remover_regex.sub('',i).strip() for i in locations]

        cars_params_patched=clean_nested(cars_params)
        infos_labels_patched=clean_nested(infos_labels)
        infos_details_patched=clean_nested(infos_details)
        tech_labels_patched=clean_nested(tech_labels)
        tech_details_patched=clean_nested(tech_details)

        all_titles_patched=clean_nested(all_titles)
        all_items_patched=[clean_nested(i) for i in all_items]
        return [cars_models_patched,cars_description_patched,
                cars_prices_patched,cars_params_patched,
                individual_urls,infos_labels_patched,
                infos_details_patched,tech_labels_patched,
                tech_details_patched,locations_patched
                ,all_titles_patched,all_items_patched,status]
    return clean_cars_data

# %%
@data_cleaner
def get_cars_info(page_url):
    r=requests.get(page_url)
    r.encoding = r.apparent_encoding
    cars_models,cars_description,cars_prices,cars_params,individual_urls,locations,status=get_info_of_cars_on_page(r)
    infos_labels=[]
    infos_details=[]
    tech_labels=[]
    tech_details=[]
    all_titles=[]
    all_items=[]
    for url in individual_urls:
        info_label,info_detail,tech_label,tech_detail,titles,items=get_individual_car_cards_info(url)
        infos_labels.append(info_label)
        infos_details.append(info_detail)
        tech_labels.append(tech_label)
        tech_details.append(tech_detail)
        all_titles.append(titles)
        all_items.append(items)
    return [cars_models,cars_description,cars_prices,cars_params,individual_urls,infos_labels,infos_details,tech_labels,tech_details,locations,all_titles,all_items,status]

# %%
def get_cars_in_pages(pages):
    #cars_data=get_cars_info(URL)
    cars_data=get_cars_info(f'{URL}/p-{int(pages[0])}')
    for i in pages[1:]:
        cars=get_cars_info(f'{URL}/p-{int(i)}')
        for j in range(len(cars_data)):
            cars_data[j]=cars_data[j]  + cars[j]
    return cars_data

# %%
from concurrent.futures import ThreadPoolExecutor
def get_cars_in_pages_threaded(pages,threads):
    with ThreadPoolExecutor(threads) as pool:
        pages=np.array_split(pages,threads)
        result=[pool.submit(get_cars_in_pages,i) for i in pages]
        cars_data=result[0].result()
        for i in result[1:]:
            cars=i.result()
            for j in range(len(cars_data)):
                cars_data[j]=cars_data[j]  + cars[j]
    return cars_data

# %%
#cars_data=get_cars_in_pages(np.linspace(2,150,size,dtype=np.int64))
#cars_data=get_cars_in_pages(np.arange(2,10))
cars_data=get_cars_in_pages_threaded(np.arange(2,10),4)
cars_data
# Out:
# [['Audi A3 Реален Пробег ! Обслужен !',
#   'Audi A3 SPORTBACK 1.4 TFSI 122hp',
#   'Audi A3 Keyless Full led',
#   'Audi A3 2.0 TFSI',
#   'Audi A3 1.4i',
#   'Audi A3 QUATTRO 3xS-LINE',
#   'Audi A4 2, 0',
#   'Audi A4 2.0d 140k 6ск италия',
#   'Audi A4 1.9TDI 131кс. 6 скорости S-line',
#   'Audi A4 1.9TDI-131 6SK',
#   'Audi A4 2.0TDI-140к.с.-ИТАЛИЯ-6скорости-Sline-',
#   'Audi A4 1.9TDI* REALNI KM*',
#   'Audi A4 3, 2 Quatro ОБСЛУЖЕН, ТОП',
#   'Audi A4',
#   'Audi A4 2.0TDI НОВ ВНОС',
#   'Audi A4',
#   'Audi A4 2.0tdi 120ks 6sk!',
#   'Audi A4 1.8 TFSI',
#   'Audi A3 Mild Hybrid/3xSline/35TFSI/Limousine/Обслужена/B&O',
#   'Audi A4 1.8 TFSI',
#   'Audi A4 QUATTRO / DISTRONIC / NAVI',
#   'Audi A4 2.0TDI NAVI* СОБСТВЕН ЛИЗИНГ* БАРТЕР',
#   'Audi A4 1.8 S line',
#   'Audi A4 2.0 TDi 143кс! 6ck!NAVI! Bi XENON !TOP !',
#   'Audi A4 2.0TFSI* Кожа* QUATTRO*',
#   'Audi A4 = 3.0TDI= S LINE= 245HP= НАВИГАЦИЯ =',
#   'Audi A4 2.0TD-S-LINE QUATTRO',
#   'Audi A4 163.000km-NEW-2.0TDI-150hp-NAVI-LED-AUTOMAT',
#   'Audi A4 2.0 / 8ZF / Quattro',
#   'Audi A4',
#   'Audi A4',
#   'Audi A4 35TFSI Mild-Hybrid',
#   'Audi A4 3.0TDI* DIGITAL* S-LINE* MATRIX* DISTRONIC*',
#   'Audi A4 2.0TFSI* QUATTRO* LED* VIRTUAL*',
#   'Audi A4 2.0TDi-190ps DSG* QUATTRO* 2017г. СЕРВИЗНА ИСТОРИЯ',
#   'Audi A4 2.0-TDI-190hp-quattro-149.000km-ORIGINAL-S-line+',
#   'Audi A4 2.0 TFSI QUATTRO 56000 km, ГАРАНЦИЯ',
#   'Audi A4 A4 B8, 5 3.0 TDI QUATTRO',
#   'Audi A4 2, 0TDi FULL OPTIONS 190k.c. Digital Cocpit S-Line',
#   'Audi A4 50TDI/B&O/3xS-Line/KAMERA 360/DISTRONIC/MATRIX',
#   'Audi A4 Quattro, 2.0 TFSI, MATRIX',
#   'Audi A4 40TDI MATRIX LED',
#   'Audi A4',
#   'Audi A4 В-Гаранция 2.0 TDI A/T 150кс',
#   'Audi A4 Allroad 2.0T PREMIUM',
#   'Audi A4 Allroad 3.0TDi 4x4 KEYLESS НАВИГАЦИЯ КОЖА ПОДГРЕВ',
#   'Audi A4 Allroad 3.0TDI 272кс 8ск NAVI XENON DriveSelect',
#   'Audi A4 Allroad 40TDI QUATTRO MILD HYBRID',
#   'Audi A5 * S-LINE* СЕДАН/5ВРАТИ* REKARO* NAVI* ТЕМПОМАТ*',
#   'Audi A5 TFSI QUATRO 5 врати',
#   'Audi A5 SPORTBACK',
#   'Audi A5 ! S-LINE/3.0TDI/QUATTRO/ВСИЧКО ПЛАТЕНО !',
#   'Audi A5 S_LINE! 3.0TDI! 4X4! FULL! NOVA!!!',
#   'Audi A5 2.0 TDI  ЛИЗИНГ',
#   'Audi A5 2.0TDI FACELIFT S-Line',
#   'Audi A5 INDIVIDUAL/S-LINE/BANG&OLUFSEN/CAMERA/ПОДГРЕВ/LIZI',
#   'Audi A4 40 TDI QUATTRO ГАРАНЦИОНЕН',
#   'Audi A5 QUATTRO* SWISS* Facelift* 3xS-line* ЛИЗИНГ',
#   'Audi A5 S-LINE/FACE/3.0TDI/DISTR/LINE ASSYST/ПОДГРЕВ/LIZIN',
#   'Audi A5 Quattro 2.0 TFSI',
#   'Audi A5 S-LINE/3.0TDI/GERMANY/DISTR/CAMERA/ПОДГРЕВ/LIZING',
#   'Audi A5 S-line+ /Distronik/Easyopen/Keyless/Digital/F1',
#   'Audi A5 Virtual Cockpit/Hybrid/Led',
#   'Audi A5 360 camera, наличен във БГ, 40 TDI, S-Line, Matrix',
#   'Audi A5 &#128285; Sportback S line Quattro 40 TDI',
#   'Audi A6 3.0TDI 224кс',
#   'Audi A6 2, 4i bi-fuel GPL, 165k.c., лимо, авто, климатр.,',
#   'Audi A6',
#   'Audi A6',
#   'Audi A6 3.0D239hp.ЕЛ СЕДАЛКИ* МЕМОРИ* QUATRO?ЛИЗИНГ?',
#   'Audi A6 3.0D* 233hp.QUATTRO* NAVI* КАТО НОВА* ЛИЗИНГ-БАРТЕ',
#   'Audi A6 3.0d* 239 ПАНОРАМА* ПОДГРЕВ* ЕЛ СЕДАЛКИ* FUL',
#   'Audi A6 4.2 Швейцария',
#   'Audi A6',
#   'Audi A6 3.0TDI S-Line Plus Black Edition',
#   'Audi A5 2.0 TDI Sportback S-line ПЪЛНА СЕРВИЗНА ИСТОРИЯ',
#   'Audi A6 2.0Tdi Select Drive.',
#   'Audi A6 FULL LED, БЕЗ КОМЕНТАР',
#   'Audi A6 BI TDI 313 4X4',
#   'Audi A6 3.0 TFSI',
#   'Audi A6 3.0 TDI QUATRO  245 PS.',
#   'Audi A6 /3.0 245 к.с./QUAT/FUL LED/NAVI',
#   'Audi A6 3.0 245 2012 S-line Quattro F1, Камера',
#   'Audi A6 3.0TDI 245кс S-tronic',
#   'Audi A6 3.0TDI лизинг през Уникредит по 365 лева на месец',
#   'Audi A6 RS6/3.0d/HEAD UP+ KAMERA+ САМОПАРКИРА+ СПОРТ/ТОП//',
#   'Audi A6 3.0 TDI S-line',
#   'Audi A6 * BiTDI-313HP* QUATTRO* ПОДГРЕВ* S-LINE*',
#   'Audi A6 100000 Реални/FULL/NIGHT/MATRIX/HED UP/KAY LESS/',
#   'Audi A6 3.0 TDI, Facelift, 4x4, внос от Германия',
#   'Audi A6   FACE  ACC  TOP',
#   'Audi A6 2.0TDI S-Line Panorama',
#   'Audi A6 3.0TDI 245 QUATTRO НОВ ВНОС РЕГИСТРИРАН ОБСЛУЖЕН',
#   'Audi A6 313KS/S-LINE/GERMANY/SPORT SOUND/ПОДГРЕВ/AUTO H/LI',
#   'Audi A6 2.8FSI',
#   'Audi A6 2.0TDI 4x4 FACE 190kc.',
#   'Audi A6 3.0BiTDI-313кс лизинг през Уникредит по 365 лева',
#   'Audi A6 3.0TDI QUATTRO',
#   'Audi A6 3.0TDI-quattro',
#   'Audi A6 3.0TDI-Sline-лизинг през Уникредит по 365лв',
#   'Audi A6 S LINE 4X4 313',
#   'Audi A6 3.0t 500кс prestige',
#   'Audi A6 3.0Tdi Matrix Sline',
#   'Audi A6 S-line',
#   'Audi A6 2.0tdi S-line quattro Sport paket plus plus plus',
#   'Audi A6 FACE/S-PAKET-2.0 TDI/FULL-УНИКАТ',
#   'Audi A6 КАПАРИРАНА !!!',
#   'Audi A6 * 3.0BITDI* SLINE* QUATTRO* ВНОС ШВЕЙЦАРИЯ',
#   'Audi A6 BiTurbo 313к.с S-line+ + + Matrix ШВЕЙЦАРИЯ',
#   'Audi A6 3.0Tdi 2018г Matrix Sline',
#   'Audi A6 3.0TDi-272hp FACELIFT* DISTRONIC, КАМЕРА* 124хил.к',
#   'Audi A6 Matrix, Kamera, 3xS-line, Дистроник, Реални км.',
#   'Audi A6 MATRIX/ПОДГРЕВ/ОБД/DISTRON/ПОДГРЕВ/MEMORY/KEYLESS/',
#   'Audi A6 S-line/FACE/NAVI/LED/СОБСТВЕН ЛИЗИНГ',
#   'Audi A6 3.0tdi-218kc-face-matrix full led',
#   'Audi A6 3.0 TDI* 326к.с * COMPETITION* S-Line* Matrix',
#   'Audi A6 AVANT S-LINE ЦЕНИ ЗА ТЪРГОВЦИ',
#   'Audi A6 3.0TDI/COMPETITION/3xS-LINE/DISTRONIC/KAMERA/TOP',
#   'Audi A6 3.0BITDI-COMPETITION-Лизинг през Уникредит',
#   'Audi A6 A6 Quattro; 40TDI; Digital Matrix; Full!!!',
#   'Audi A6 50TDI ОБСЛУЖЕНА! Matrix фарове, Memory, Head Up',
#   'Audi A6 AVANT 40 TDI',
#   'Audi A6 S6 50TDI 4x4 DIGITAL MATRIX-HD 3D-CAM ACC+ ВАККУМ',
#   'Audi A6 Allroad 50 TDI Quattro Bang&Olufsen',
#   'Audi A6 * ПРОДАДЕН*',
#   'Audi A6 Allroad EXCLUSIVE 4X4',
#   'Audi A6 Allroad * S-LINE* FACE* MATRIX* PANORAMA*',
#   'Audi A6 Allroad MATRIX/GERMANY/KEYLES/КАМЕРА/LED/RECARO/MEMORY/TOP',
#   'Audi A6 Allroad Bi-Tdi 320к.с.-quattro-8ZF- MATRIX',
#   'Audi A6 Allroad * S-LINE* 3.0TDI-272HP* ПОДГРЯВАНЕ* MATRIX* ПЕРФЕК',
#   'Audi A6 Allroad MATRIX/320KS/GERMANY/PANORAMA/LED/AMBIENT/ПАМЕТ/LI',
#   'Audi A6 Allroad Night B&O Head Up Exclusive',
#   'Audi A6 40TDI QUATTRO HYBRID DIGITAL COCKPIT',
#   'Audi A6 Allroad 50 TDI Quattro Bang&Olufsen',
#   'Audi A7 3.0 TDI quattro | S tronic | BANG & OLUFSEN',
#   'Audi A7 RS7/272к.с./QUATTRO/SPORT+ /КАТО НОВА',
#   'Audi A7 S LINE',
#   'Audi A7 СМЕНЕНИ ВЕРИГИ / МАСАЖ',
#   'Audi A7 * FACE* S-LINE 2X* QUATTRO* FULL LED* КАТО НОВА*',
#   'Audi A7 MATRIX/S-LINE+ /FULL LED/GERMANY/360CAM/ПОДГРEB/LI',
#   'Audi A7 S-LINE/MATRIX/DISTR/360CAM/ПОДГРЕВ/BOSE/AUTO H/LIZ',
#   'Audi A7  COMPETIT* S-LINE/BOSE/ПОДГР/ГЕРМАНИЯ ЛИЗИНГ',
#   'Audi A7 MATRIX/DISTR/S-line/3D-KAMERA/ГЕРМАНИЯ ЛИЗИНГ',
#   'Audi A7 50TDI Quattro S Line Bang&Olufsen',
#   'Audi A7 S7/MATRIX/DISTR/HEAD UP/NIGHT/ВАКУМ/3DCAM/4BANG/PA',
#   'Audi A8 4.2 TDI* КАМЕРА* KEYLESS* BOSE* 4ZONE* TOP',
#   'Audi A8 * БАРТЕР* Вакум* Масаж*',
#   'Audi A8 4.2TDI* MATRIX* SOFTCLOSE* BOSE* KEYLESS',
#   'Audi A8 4.2TDI/FULL LED/DISTRON/CAMERA/ПОДГРEB/BOSE/F1/LIZ',
#   'Audi A8 * 4.2TDI* FULL-LED* NIGHT-VISION* INDIVIDUAL* B&O*',
#   'Audi A8 Matrix//4.2tdi',
#   'Audi A7 3.0 TDI'],
#  ['Нов Внос от Швейцария в безупречно техническо и визуално състояние! Оригинален вид (боя-салон) и Без Забележки! Доказано здрав и супер икономичен двигател двигател 1. 6тди-110кс! Напълно обслужен преди 2хил. км. ! Обявата е с видеоклип на автомобила!  Възможен кредит чрез Уникредит, TBI bank, бързо и лесно одобрение на място.  За повече информация на тел: 0879177662  <br>Особености - 4(5) Врати, Auto Start Stop function, Bluetooth \\ handsfree система, DVD, TV, GPS система за проследяване, LED фарове, Steptronic, Tiptronic, USB, audio\\video, IN\\AUX изводи, Автоматичен контрол на стабилността, Адаптивни предни светлини, Аларма, Антиблокираща система, Блокаж на диференциала, Бордкомпютър, Въздушни възглавници - Задни, Въздушни възглавници - Предни, Въздушни възглавници - Странични, Датчик за светлина, Ел. Огледала, Ел. Стъкла, Електронна програма за стабилизиране, Климатроник, Контрол на налягането на гумите, Лети джанти, Металик, Навигация, Напълно обслужен, Нов внос, Парктроник, Подгряване на предното стъкло, Подгряване на седалките, Регулиране на волана, Сензор за дъжд, Сервизна книжка, Серво усилвател на волана, Система ISOFIX, Система за динамична устойчивост, Система за защита от пробуксуване, Система за измиване на фаровете, Система за контрол на скоростта (автопилот), Система за подпомагане на спирането, Стерео уредба, Халогенни фарове, Хладилна жабка, Централно заключване',
#   'Продавам AUDI A3, SPORTBACK 1. 4 TFSI, бензин 90kw/122hp 8VA. Колата е напълно обслужена и в безупречно състояние. Запазен и отлично поддържан автомобил, който е в движение и се кара всеки ден. Продава се с два оригинални ключа. Разход на гориво около 6л/100км извънградско и 8л/100км градско. Платени пълно автокаско и гражданска, валидни до 12. 01. 2025г. Винетка, валидна до 03. 02. 2025г. Пълен S-line пакет. Фабрично затъмнени стъкла. Автоматична 7-степенна скоростна кутия S-tronic. Озвучителна система BANG & OLUFSEN. LED пакет - фарове, стопове, мигачи, интериорно осветление и др. Най-висок клас за модела автоматични ксенон-фарове със система за измиване. Сензор за дъжд. 18&#34; оригинални джанти с чисто нови летни гуми - Continental Premium Contact 7. Автоматични странични огледала. Безключово запалване, отключване и заключване. Двузонов климатроник. Auto-hold функция. Фарове за мъгла. Резервна гума. Колата се съхранява в гараж. Може да се провери в сервиз по Ваш избор в границите на гр. София.<br>Особености - 4(5) Врати, Auto Start Stop function, Bluetooth \\ handsfree система, GPS система за проследяване, Steptronic, Tiptronic, USB, audio\\video, IN\\AUX изводи, Аларма, Антиблокираща система, Безключово палене , Бордкомпютър, Бързи \\ бавни скорости, Въздушни възглавници - Задни, Въздушни възглавници - Предни, Въздушни възглавници - Странични, Датчик за светлина, Ел. Огледала, Ел. Стъкла, Ел. разпределяне на спирачното усилие, Ел. усилвател на волана, Електронна програма за стабилизиране, Каско, Климатроник, Кожен салон, Контрол на налягането на гумите, Ксенонови фарове, Лети джанти, Металик, Мултифункционален волан, Навигация, Напълно обслужен, Парктроник, Подгряване на предното стъкло, Регулиране на волана, С регистрация, Сензор за дъжд, Серво усилвател на волана, Система ISOFIX, Система за защита от пробуксуване, Система за измиване на фаровете, Система за контрол на скоростта (автопилот), Система
но почистване и изпиране на целия интериор, третиране на кожения салон и всички кожени елементи с професионални препарати за кожа, детайлно почистване на екстериора, полиране на лаково покритие и третиране на всички матови и хромирани елементи със съответните професионални препарати. Процедурата е извършена при най-добрите специалисти в гр. Варна - &#34; Топ Гиър Карс&#34; също внася автомобили и други превозни средства от САЩ и Канада по избор на клиента в най-бързи срокове и конкурентни цени.<br>Особености - 4(5) Врати, 4x4, Bluetooth \\ handsfree система, LED фарове, Автоматичен контрол на стабилността, Аларма, Антиблокираща система, Бордкомпютър, Въздушни възглавници - Предни, Въздушни възглавници - Странични, Датчик за светлина, Ел. Огледала, Ел. Стъкла, Ел. разпределяне на спирачното усилие, Ел. регулиране на седалките, Ел. усилвател на волана, Електронна програма за стабилизиране, Климатик, Кожен салон, Контрол на налягането на гумите, Лети джанти, Металик, Мултифункционален волан, Навигация, Нов внос, Подгряване на седалките, Регулиране на волана, Сензор за дъжд, Серво усилвател на волана, Система ISOFIX, Система за защита от пробуксуване, Стерео уредба, Централно заключване, Шибедах',
#   '===Нов внос Италия===                             ===ВАЖНО! ! ! ВАЖНО! ! ! ВАЖНО! ! ! === =ДОБРО ТЕХНИЧЕСКО И ВИЗУАЛНО СЪСТОЯНИЕ= =ДОБРА РАБОТА НА ДВИГАТЕЛ И СКОРОСТИ= =BI XENON ФАРОВЕ+СИСТЕМА ЗА ИЗМИВАНЕ= =ДВИГАТЕЛ 3. 0TDI 245 КОНСКИ СИЛИ= =QUATTRO 4X4= =ПЪЛЕН S LINE= =ПАНОРАМЕН ТАВАН= =КОЖЕН РЕКАРО САЛОН= =АВТОПИЛОТ= =АВТОМАТИЧНА СКОРОСТНА КУТИЯ= =НАВИГАЦИОННА СИСТЕМА= =ПОДЛАКЪТНИК= =ПЕРА ЗА СМЯНА НА СКОРОСТИТЕ ОТ ВОЛАНА= =КЪП ХОЛДЕРИ= =КЛИМАТРОНИК= =АЛИМИНИЕВИ ЛЕТИ ДЖАНТИ R18= =РЕЙЛИНГ= =ПРИБИРАНЕ НА ОГЛЕДАЛА= =ХАЛОГЕННИ СВЕТЛИНИ= ***АВТОКЪЩА &#34; REFINED AUTO&#39;&#39; е директен вносител на автомобили с доказан произход. Внася ПОДБРАНИ автомобили от ШВЕЙЦАРИЯ=ИТАЛИЯ=ГЕРМАНИЯ И КАНАДА. Богат избор на всички марки автомобили на най ДОБРИТЕ цени на пазара. *** ***АВТОКЪЩА REFINED AUTO ПРЕДЛАГА СЛЕДНИТЕ УСЛОВИЯ НА СВОИТЕ КЛИЕНТИ*** ***РЕГИСТРАЦИЯ НА ЗАКУПЕНИТЕ АВТОМОБИЛИ*** ***ИЗВАЖДАНЕ НА ТРАНЗИТНИ НОМЕРА*** ***ГРАЖДАНСКА ОТГОВОРНОТ*** ***АВТОКАСКО+МАРКИРОВКА*** *** ОБСЛУЖВАНЕ В ДОВЕРЕНИ СЕРВИЗИ НА ПРЕФЕРЕНЦИАЛНИ ЦЕНИ*** ***СЪДЕЙСТВИЕ ЗА ИЗГОТВЯНЕ НА ЛИЗИНГ ЧРЕЗ ЛИЗИНГОВА КОМПАНИЯ С 30% ПЪРВОНАЧАЛНА ВНОСКА И РАЗРОЧВАНЕ ДО 36 МЕСЕЦА*** ***ВЪЗМОЖНОСТ ЗА ПРЕГЛЕД В ДОВЕРЕН НА КЛИЕНТА СЕРВИЗ*** ***РАБОТНО ВРЕМЕ*** ***ПОНЕДЕЛНИК-ПЕТЪК 9: 00=18: 00*** ***СЪБОТА 10: 00=17: 00*** ***НЕДЕЛЯ ПОЧИВЕН ДЕН***<br>Особености - 4(5) Врати, 4x4, Auto Start Stop function, Bluetooth \\ handsfree система, DVD, TV
събота: 10: 00 - 13: 00, Неделя - ПОЧИВЕН ДЕН! ! !  За повече информация не се притеснявайте, а звъннете на посочения телефон!<br>Особености - 4(5) Врати, 4x4, Auto Start Stop function, Bluetooth \\ handsfree система, DVD, TV, GPS система за проследяване, LED фарове, Steptronic, Tiptronic, USB, audio\\video, IN\\AUX изводи, Автоматичен контрол на стабилността, Адаптивни предни светлини, Аларма, Антиблокираща система, Бартер, Безключово палене , Въздушни възглавници - Задни, Въздушни възглавници - Предни, Въздушни възглавници - Странични, Датчик за светлина, Ел. Огледала, Ел. Стъкла, Ел. разпределяне на спирачното усилие, Електронна програма за стабилизиране, Климатроник, Контрол на налягането на гумите, Ксенонови фарове, Лети джанти, Лизинг, Металик, Мултифункционален волан, Навигация, Нов внос, Парктроник, Подгряване на седалките, Регулиране на волана, Сензор за дъжд, Серво усилвател на волана, Система ISOFIX, Система за защита от пробуксуване, Система за измиване на фаровете, Система за контрол на дистанцията, Система за контрол на скоростта (автопилот), Система за подпомагане на спирането, Стерео уредба, Халогенни фарове, Хладилна жабка, Централно заключване',
# ...
#     'Ел. разпределяне на спирачното усилие',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за защита от пробуксуване',
#     'Система за контрол на дистанцията',
#     'Система за контрол на спускането',
#     'Система за подпомагане на спирането'],
#    ['4x4', 'Buy back', 'Бартер', 'Лизинг', 'Нов внос'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Лети джанти',
#     'Металик',
#     'Спойлери',
#     'Халогенни фарове'],
#    ['Аларма', 'Централно заключване'],
#    ['Кожен салон'],
#    ['Auto Start Stop function',
#     'Bluetooth \\ handsfree система',
#     'DVD, TV',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Безключово палене',
#     'Блокаж на диференциала',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба',
#     'Хладилна жабка']],
#   [['GPS система за проследяване',
#     'Автоматичен контрол на стабилността',
#     'Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Ел. разпределяне на спирачното усилие',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за защита от пробуксуване',
#     'Система за изсушаване на накладките',
#     'Система за контрол на дистанцията',
#     'Система за контрол на спускането',
#     'Система за подпомагане на спирането'],
#    ['4x4', 'Бартер', 'Лизинг', 'Нов внос', 'Сервизна книжка'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Ксенонови фарове',
#     'Лети джанти',
#     'Металик',
#     'Халогенни фарове',
#     'Шибедах'],
#    ['Аларма', 'Централно заключване'],
#    ['Кожен салон'],
#    ['Auto Start Stop function',
#     'Bluetooth \\ handsfree система',
#     'DVD, TV',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Блокаж на диференциала',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Отопление на волана',
#     'Печка',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба',
#     'Термопомпа',
#     'Хладилна жабка']],
#   [['GPS система за проследяване',
#     'Автоматичен контрол на стабилността',
#     'Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Ел. разпределяне на спирачното усилие',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за защита от пробуксуване',
#     'Система за контрол на дистанцията',
#     'Система за контрол на спускането',
#     'Система за подпомагане на спирането'],
#    ['4x4', 'Бартер', 'Лизинг', 'Нов внос', 'Сервизна книжка'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Ксенонови фарове',
#     'Лети джанти',
#     'Металик',
#     'Халогенни фарове'],
#    ['Аларма', 'Централно заключване'],
#    ['Кожен салон'],
#    ['Auto Start Stop function',
#     'Bluetooth \\ handsfree система',
#     'DVD, TV',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Блокаж на диференциала',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Отопление на волана',
#     'Печка',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба',
#     'Термопомпа',
#     'Хладилна жабка']],
#   [['Автоматичен контрол на стабилността',
#     'Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за защита от пробуксуване',
#     'Система за контрол на дистанцията',
#     'Система за подпомагане на спирането'],
#    ['4x4', 'Buy back', 'Бартер', 'Лизинг', 'Нов внос', 'Сервизна книжка'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Лети джанти',
#     'Металик',
#     'Панорамен люк',
#     'Спойлери'],
#    ['Централно заключване'],
#    ['Кожен салон'],
#    ['Auto Start Stop function',
#     'Bluetooth \\ handsfree система',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба',
#     'Хладилна жабка']],
#   [['GPS система за проследяване',
#     'Автоматичен контрол на стабилността',
#     'Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Ел. разпределяне на спирачното усилие',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за защита от пробуксуване',
#     'Система за контрол на дистанцията',
#     'Система за контрол на спускането',
#     'Система за подпомагане на спирането'],
#    ['4x4',
#     'Buy back',
#     'Бартер',
#     'Лизинг',
#     'Напълно обслужен',
#     'Нов внос',
#     'С регистрация',
#     'Сервизна книжка',
#     'Тунинг'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Ксенонови фарове',
#     'Лети джанти',
#     'Металик',
#     'Панорамен люк',
#     'Спойлери',
#     'Халогенни фарове'],
#    ['Аларма', 'Каско', 'Централно заключване'],
#    ['Кожен салон'],
#    ['Auto Start Stop function',
#     'Bluetooth \\ handsfree система',
#     'DVD, TV',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Блокаж на диференциала',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Печка',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба',
#     'Хладилна жабка']],
#   [['Автоматичен контрол на стабилността',
#     'Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Електронна програма за стабилизиране',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за защита от пробуксуване',
#     'Система за контрол на дистанцията'],
#    ['4x4', 'С регистрация'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Ксенонови фарове',
#     'Лети джанти',
#     'Металик',
#     'Теглич',
#     'Шибедах'],
#    ['Централно заключване'],
#    ['Bluetooth \\ handsfree система',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Печка',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба']],
#   [['4x4', 'Buy back', 'Бартер']],
#   [],
#   [['GPS система за проследяване',
#     'Автоматичен контрол на стабилността',
#     'Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Ел. разпределяне на спирачното усилие',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за защита от пробуксуване',
#     'Система за контрол на дистанцията',
#     'Система за подпомагане на спирането'],
#    ['4x4', 'Buy back', 'Бартер', 'Лизинг', 'Нов внос', 'С регистрация'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Лети джанти',
#     'Металик',
#     'Спойлери',
#     'Халогенни фарове'],
#    ['Аларма', 'Централно заключване'],
#    ['Auto Start Stop function',
#     'Bluetooth \\ handsfree система',
#     'DVD, TV',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Блокаж на диференциала',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба',
#     'Хладилна жабка']],
#   [['GPS система за проследяване',
#     'Автоматичен контрол на стабилността',
#     'Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Ел. разпределяне на спирачното усилие',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за изсушаване на накладките',
#     'Система за подпомагане на спирането'],
#    ['4x4',
#     'Бартер',
#     'Къса база',
#     'Лизинг',
#     'Напълно обслужен',
#     'С регистрация'],
#    ['4(5) Врати', 'LED фарове', 'Лети джанти', 'Металик', 'Шибедах'],
#    ['Аларма', 'Каско', 'Централно заключване'],
#    ['Кожен салон'],
#    ['Bluetooth \\ handsfree система',
#     'DVD, TV',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Печка',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Система за контрол на скоростта (автопилот)',
#     'Стерео уредба',
#     'Хладилна жабка']],
#   [['Парктроник', 'Система ISOFIX'],
#    ['4x4', 'Напълно обслужен', 'С регистрация'],
#    ['4(5) Врати',
#     'LED фарове',
#     'Ксенонови фарове',
#     'Лети джанти',
#     'Металик',
#     'Халогенни фарове',
#     'Шибедах'],
#    ['Централно заключване'],
#    ['Кожен салон'],
#    ['Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Блокаж на диференциала',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Печка',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Серво усилвател на волана',
#     'Система за измиване на фаровете',
#     'Хладилна жабка']],
#   [['Адаптивни предни светлини',
#     'Антиблокираща система',
#     'Въздушни възглавници - Задни',
#     'Въздушни възглавници - Предни',
#     'Въздушни възглавници - Странични',
#     'Ел. разпределяне на спирачното усилие',
#     'Електронна програма за стабилизиране',
#     'Контрол на налягането на гумите',
#     'Парктроник',
#     'Система ISOFIX',
#     'Система за динамична устойчивост',
#     'Система за защита от пробуксуване',
#     'Система за изсушаване на накладките',
#     'Система за контрол на дистанцията',
#     'Система за контрол на спускането',
#     'Система за подпомагане на спирането'],
#    ['4x4', 'Лизинг', 'С регистрация'],
#    ['4(5) Врати', 'Лети джанти', 'Металик'],
#    ['Кожен салон'],
#    ['Auto Start Stop function',
#     'DVD, TV',
#     'Steptronic, Tiptronic',
#     'USB, audio\\video, IN\\AUX изводи',
#     'Адаптивно въздушно окачване',
#     'Безключово палене',
#     'Блокаж на диференциала',
#     'Бордкомпютър',
#     'Датчик за светлина',
#     'Ел. Огледала',
#     'Ел. Стъкла',
#     'Ел. регулиране на окачването',
#     'Ел. регулиране на седалките',
#     'Ел. усилвател на волана',
#     'Климатроник',
#     'Мултифункционален волан',
#     'Навигация',
#     'Отопление на волана',
#     'Подгряване на предното стъкло',
#     'Подгряване на седалките',
#     'Регулиране на волана',
#     'Сензор за дъжд',
#     'Стерео уредба',
#     'Хладилна жабка']]],
#  ['TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'TOP',
#   'SHORT']]

# %%
def combine_labels(source):
    result=source[0]
    for labels in source[1:]:
        result+=labels
    return list(set(result))

# %%
all_tech_labels=combine_labels(cars_data[-6])
all_info_labels=combine_labels(cars_data[-8])
all_titles=combine_labels(cars_data[-3])
all_titles
# Out:
# ['Защита', 'Безопасност', 'Интериор', 'Други', 'Комфорт', 'Екстериор']

# %%
def get_as_dicts(keys,values):
    result=[]
    for labels,data in zip(keys,values):
        current={}
        for label,value in zip(labels,data):
            current[label]=value
        result.append(current)
    return result

# %%
infos_as_dicts=get_as_dicts(cars_data[5],cars_data[6])
tech_as_dict=get_as_dicts(cars_data[7],cars_data[8])

# %%
additional_data_for_car=get_as_dicts(cars_data[10],cars_data[11])
additional_data_for_car
# Out:
# [{'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за подпомагане на спирането'],
#   'Други': ['Напълно обслужен', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['Напълно обслужен', 'С регистрация'],
#   'Екстериор': ['4(5) Врати',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Спойлери'],
#   'Защита': ['Аларма', 'Каско', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Бързи \\ бавни скорости',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване'],
#   'Други': ['Лизинг',
#    'Напълно обслужен',
#    'Нов внос',
#    'С регистрация',
#    'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Каско', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията'],
#   'Други': ['Напълно обслужен', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Панорамен люк',
#    'Спойлери',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Каско', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване'],
#   'Други': ['Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване'],
#   'Други': ['4x4',
#    'Напълно обслужен',
#    'Нов внос',
#    'С регистрация',
#    'Сервизна книжка',
#    'Тунинг'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване'],
#   'Други': ['Buy back', 'Нов внос'],
#   'Екстериор': ['4(5) Врати', 'Лети джанти', 'Металик', 'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Блокаж на диференциала',
#    'Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['Напълно обслужен', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати', 'Лети джанти', 'Металик', 'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични'],
#   'Други': ['Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Комфорт': ['Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Серво усилвател на волана',
#    'Стерео уредба']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране'],
#   'Други': ['Лизинг', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати', 'Лети джанти', 'Металик', 'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Регулиране на волана',
#    'Серво усилвател на волана',
#    'Стерео уредба']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Система за защита от пробуксуване'],
#   'Други': ['Нов внос'],
#   'Екстериор': ['4(5) Врати', 'Лети джанти', 'Металик', 'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Система ISOFIX'],
#   'Други': ['4x4', 'Бартер', 'Напълно обслужен', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Теглич',
#    'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Интериор': ['Велурен салон'],
#   'Комфорт': ['Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Електронна програма за стабилизиране',
#    'Система за подпомагане на спирането'],
#   'Екстериор': ['4(5) Врати', 'LED фарове', 'Ксенонови фарове'],
#   'Защита': ['Аларма'],
#   'Комфорт': ['Безключово палене',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Стерео уредба']},
#  {'Безопасност': ['Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник'],
#   'Други': ['Лизинг', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Други': ['С регистрация', 'Сервизна книжка'], 'Екстериор': ['4(5) Врати']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване'],
#   'Други': ['Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни'],
#   'Други': ['Напълно обслужен', 'С регистрация'],
#   'Екстериор': ['4(5) Врати', 'LED фарове'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Steptronic, Tiptronic', 'Ел. Огледала', 'Климатик']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за контрол на дистанцията'],
#   'Други': ['Напълно обслужен', 'С регистрация', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Каско', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни'],
#   'Други': ['Напълно обслужен', 'С регистрация'],
#   'Екстериор': ['4(5) Врати', 'LED фарове'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Steptronic, Tiptronic', 'Ел. Огледала', 'Климатик']},
#  {'Безопасност': ['Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Напълно обслужен', 'С регистрация'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Ел. Стъкла',
#    'Климатик',
#    'Мултифункционален волан',
#    'Навигация',
#    'Сензор за дъжд']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване',
#    'Система за подпомагане на спирането'],
#   'Други': ['Buy back', 'Бартер', 'Лизинг', 'Нов внос'],
#   'Екстериор': ['4(5) Врати', 'Лети джанти', 'Металик', 'Рейлинг на покрива'],
#   'Защита': ['Централно заключване'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатик',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Парктроник',
#    'Система за защита от пробуксуване'],
#   'Други': ['Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Спойлери',
#    'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Интериор': ['Велурен салон', 'Кожен салон'],
#   'Комфорт': ['Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за подпомагане на спирането'],
#   'Други': ['Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Антиблокираща система',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване'],
#   'Други': ['4x4', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатик',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Стерео уредба']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване'],
#   'Други': ['4x4', 'Бартер', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Лизинг', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Интериор': ['Велурен салон'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за подпомагане на спирането'],
#   'Други': ['Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на спускането'],
#   'Други': ['4x4', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Панорамен люк'],
#   'Защита': ['Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система за защита от пробуксуване'],
#   'Други': ['Напълно обслужен', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Теглич',
#    'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатик',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Система за защита от пробуксуване'],
#   'Други': ['4x4'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Панорамен люк',
#    'Халогенни фарове',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатик',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['Нов внос', 'С регистрация'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Спойлери',
#    'Теглич'],
#   'Защита': ['Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Бартер', 'Лизинг', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за изсушаване на накладките',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Бартер', 'Лизинг', 'Напълно обслужен', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4',
#    'Лизинг',
#    'Напълно обслужен',
#    'Нов внос',
#    'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за изсушаване на накладките',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Напълно обслужен', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Панорамен люк',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Отопление на волана',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['Лизинг', 'Напълно обслужен', 'С регистрация'],
#   'Екстериор': ['4(5) Врати', 'LED фарове', 'Лети джанти', 'Металик'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Бартер', 'Лизинг', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за изсушаване на накладките',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Напълно обслужен', 'С регистрация', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати', 'LED фарове', 'Лети джанти', 'Металик'],
#   'Защита': ['Аларма', 'Каско', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Бързи \\ бавни скорости',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Екстериор': ['4(5) Врати', 'Лети джанти', 'Теглич', 'Халогенни фарове'],
#   'Защита': ['Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за изсушаване на накладките',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['Напълно обслужен', 'Нов внос', 'С регистрация'],
#   'Защита': ['Каско'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['Лизинг', 'Напълно обслужен', 'С регистрация', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Каско', 'Централно заключване'],
#   'Интериор': ['Велурен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Контрол на налягането на гумите'],
#   'Други': ['4x4', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Ел. Огледала',
#    'Ел. Стъкла',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Лизинг', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4',
#    'Buy back',
#    'Бартер',
#    'Лизинг',
#    'Напълно обслужен',
#    'Нов внос',
#    'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Рейлинг на покрива',
#    'Халогенни фарове'],
#   'Защита': ['OFFROAD пакет', 'Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
# ...
#    'Металик',
#    'Спойлери',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Buy back', 'Бартер', 'Лизинг', 'Нов внос'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Спойлери',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за изсушаване на накладките',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Бартер', 'Лизинг', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Отопление на волана',
#    'Печка',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Термопомпа',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Бартер', 'Лизинг', 'Нов внос', 'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Отопление на волана',
#    'Печка',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Термопомпа',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4',
#    'Buy back',
#    'Бартер',
#    'Лизинг',
#    'Нов внос',
#    'Сервизна книжка'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Панорамен люк',
#    'Спойлери'],
#   'Защита': ['Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4',
#    'Buy back',
#    'Бартер',
#    'Лизинг',
#    'Напълно обслужен',
#    'Нов внос',
#    'С регистрация',
#    'Сервизна книжка',
#    'Тунинг'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Панорамен люк',
#    'Спойлери',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Каско', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Печка',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Електронна програма за стабилизиране',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията'],
#   'Други': ['4x4', 'С регистрация'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Теглич',
#    'Шибедах'],
#   'Защита': ['Централно заключване'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Печка',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба']},
#  {'Други': ['4x4', 'Buy back', 'Бартер']},
#  {},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за контрол на дистанцията',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4',
#    'Buy back',
#    'Бартер',
#    'Лизинг',
#    'Нов внос',
#    'С регистрация'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Спойлери',
#    'Халогенни фарове'],
#   'Защита': ['Аларма', 'Централно заключване'],
#   'Комфорт': ['Auto Start Stop function',
#    'Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['GPS система за проследяване',
#    'Автоматичен контрол на стабилността',
#    'Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за изсушаване на накладките',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4',
#    'Бартер',
#    'Къса база',
#    'Лизинг',
#    'Напълно обслужен',
#    'С регистрация'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Лети джанти',
#    'Металик',
#    'Шибедах'],
#   'Защита': ['Аларма', 'Каско', 'Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Bluetooth \\ handsfree система',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Печка',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Система за контрол на скоростта (автопилот)',
#    'Стерео уредба',
#    'Хладилна жабка']},
#  {'Безопасност': ['Парктроник', 'Система ISOFIX'],
#   'Други': ['4x4', 'Напълно обслужен', 'С регистрация'],
#   'Екстериор': ['4(5) Врати',
#    'LED фарове',
#    'Ксенонови фарове',
#    'Лети джанти',
#    'Металик',
#    'Халогенни фарове',
#    'Шибедах'],
#   'Защита': ['Централно заключване'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Печка',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Серво усилвател на волана',
#    'Система за измиване на фаровете',
#    'Хладилна жабка']},
#  {'Безопасност': ['Адаптивни предни светлини',
#    'Антиблокираща система',
#    'Въздушни възглавници - Задни',
#    'Въздушни възглавници - Предни',
#    'Въздушни възглавници - Странични',
#    'Ел. разпределяне на спирачното усилие',
#    'Електронна програма за стабилизиране',
#    'Контрол на налягането на гумите',
#    'Парктроник',
#    'Система ISOFIX',
#    'Система за динамична устойчивост',
#    'Система за защита от пробуксуване',
#    'Система за изсушаване на накладките',
#    'Система за контрол на дистанцията',
#    'Система за контрол на спускането',
#    'Система за подпомагане на спирането'],
#   'Други': ['4x4', 'Лизинг', 'С регистрация'],
#   'Екстериор': ['4(5) Врати', 'Лети джанти', 'Металик'],
#   'Интериор': ['Кожен салон'],
#   'Комфорт': ['Auto Start Stop function',
#    'DVD, TV',
#    'Steptronic, Tiptronic',
#    'USB, audio\\video, IN\\AUX изводи',
#    'Адаптивно въздушно окачване',
#    'Безключово палене',
#    'Блокаж на диференциала',
#    'Бордкомпютър',
#    'Датчик за светлина',
#    'Ел. Огледала',
#    'Ел. Стъкла',
#    'Ел. регулиране на окачването',
#    'Ел. регулиране на седалките',
#    'Ел. усилвател на волана',
#    'Климатроник',
#    'Мултифункционален волан',
#    'Навигация',
#    'Отопление на волана',
#    'Подгряване на предното стъкло',
#    'Подгряване на седалките',
#    'Регулиране на волана',
#    'Сензор за дъжд',
#    'Стерео уредба',
#    'Хладилна жабка']}]

# %%
df=pd.DataFrame({'CarModel':cars_data[0],'CarDescription':cars_data[1],'CarPrice':cars_data[2],'Params':cars_data[3],'URL':cars_data[4],"Location":cars_data[9],'Status':cars_data[12]})
df=df.join(pd.DataFrame(tech_as_dict),how='outer').join(pd.DataFrame(infos_as_dicts),lsuffix='Tech',rsuffix='Info').join(pd.DataFrame(additional_data_for_car))
df
# Out:
#                                               CarModel  \
# 0                   Audi A3 Реален Пробег ! Обслужен !
# 1                     Audi A3 SPORTBACK 1.4 TFSI 122hp
# 2                             Audi A3 Keyless Full led
# 3                                     Audi A3 2.0 TFSI
# 4                                         Audi A3 1.4i
# ..                                                 ...
# 147   Audi A8 4.2TDI* MATRIX* SOFTCLOSE* BOSE* KEYLESS
# 148  Audi A8 4.2TDI/FULL LED/DISTRON/CAMERA/ПОДГРEB...
# 149  Audi A8 * 4.2TDI* FULL-LED* NIGHT-VISION* INDI...
# 150                             Audi A8 Matrix//4.2tdi
# 151                                    Audi A7 3.0 TDI
#
#                                         CarDescription    CarPrice  \
# 0    Нов Внос от Швейцария в безупречно техническо ...  23 999 лв.
# 1    Продавам AUDI A3, SPORTBACK 1. 4 TFSI, бензин ...  24 500 лв.
# 2    Keyless, Full led, ксенон, подгрев, преден и з...  25 000 лв.
# 3    Обслужен на 144500км , сменени 4 нови дискове ...  32 900 лв.
# 4    Колата е в отлично състояние реални километри ...  34 900 лв.
# ..                                                 ...         ...
# 147  Здравейте, продавам Аудито от снимките 4х4 qua...  26 900 лв.
# 148  ! ! ! СОБСТВЕН ЛИЗИНГ ! ! !  БЕЗ ДОКАЗВАНЕ НА ...  32 000 лв.
# 149  Здравейте , продаваме посочения автомобил. Отл...  32 900 лв.
# 150  ! !! Ауди А8 4. 2тди 351к. с. автомобила е на ...  35 000 лв.
# 151  ! ! ! СОБСТВЕН ЛИЗИНГ ! ! !  БЕЗ ДОКАЗВАНЕ НА ...  35 000 лв.
#
#                                                 Params  \
# 0    [декември 2016 г., 107 538 км, Черен, Дизелов,...
# 1    [октомври 2013 г., 204 000 км, Сив, Бензинов, ...
# 2    [ноември 2015 г., 201 000 км, Бял, Дизелов, 15...
# 3    [юли 2017 г., 145 380 км, Бял, Бензинов, 186 к...
# 4    [септември 2017 г., 200 000 км, Черен, Бензино...
# ..                                                 ...
# 147  [януари 2013 г., 297 655 км, Бял, Дизелов, 351...
# 148  [януари 2012 г., 189 300 км, Черен, Дизелов, 3...
# 149  [декември 2011 г., 234 000 км, Черен, Дизелов,...
# 150  [февруари 2011 г., 325 000 км, Черен, Дизелов,...
# 151  [Цената е без ДДС, януари 2012 г., 243 000 км,...
#
#                                                    URL  \
# 0    www.mobile.bg/obiava-11721377192980888-audi-a3...
# 1    www.mobile.bg/obiava-11718217748914834-audi-a3...
# 2    www.mobile.bg/obiava-11697480660026130-audi-a3...
# 3    www.mobile.bg/obiava-11701528856658093-audi-a3...
# 4    www.mobile.bg/obiava-11686487589024041-audi-a3...
# ..                                                 ...
# 147  www.mobile.bg/obiava-11722101555428416-audi-a8...
# 148  www.mobile.bg/obiava-11718624679348570-audi-a8...
# 149  www.mobile.bg/obiava-11721921920601854-audi-a8...
# 150  www.mobile.bg/obiava-11718639627708473-audi-a8...
# 151  www.mobile.bg/obiava-11715084272457408-audi-a7...
#
#                       Location Status Дата на производствоTech ДвигателTech  \
# 0        обл. София, гр. София    TOP            декември 2016      Дизелов
# 1        обл. София, гр. София    TOP            октомври 2013     Бензинов
# 2     обл. Бургас, гр. Поморие    TOP             ноември 2015      Дизелов
# 3        обл. София, гр. София    TOP                 юли 2017     Бензинов
# 4        обл. София, гр. София    TOP           септември 2017     Бензинов
# ..                         ...    ...                      ...          ...
# 147        обл. Русе, гр. Бяла    TOP              януари 2013      Дизелов
# 148      обл. София, гр. София    TOP              януари 2012      Дизелов
# 149  обл. Пловдив, гр. Пловдив    TOP            декември 2011      Дизелов
# 150  обл. Габрово, гр. Дряново    TOP            февруари 2011      Дизелов
# 151      обл. Шумен, гр. Шумен  SHORT              януари 2012      Дизелов
#
#     МощностTech  ... МощностInfo ЕвростандартInfo Скоростна кутияInfo  \
# 0      110 к.с.  ...    110 к.с.           Евро 6         Автоматична
# 1      122 к.с.  ...    122 к.с.           Евро 5         Автоматична
# 2      150 к.с.  ...    150 к.с.           Евро 6         Автоматична
# 3      186 к.с.  ...    186 к.с.           Евро 5         Автоматична
# 4      150 к.с.  ...    150 к.с.           Евро 6               Ръчна
# ..          ...  ...         ...              ...                 ...
# 147    351 к.с.  ...    351 к.с.           Евро 5         Автоматична
# 148    351 к.с.  ...    351 к.с.           Евро 5         Автоматична
# 149    351 к.с.  ...    351 к.с.              NaN         Автоматична
# 150    351 к.с.  ...    351 к.с.           Евро 5         Автоматична
# 151    245 к.с.  ...    245 к.с.              NaN         Автоматична
#
#     Пробег [км]Info                                        Безопасност  \
# 0         107538 км  [GPS система за проследяване, Автоматичен конт...
# 1         204000 км  [GPS система за проследяване, Антиблокираща си...
# 2         201000 км  [GPS система за проследяване, Адаптивни предни...
# 3         145380 км  [Адаптивни предни светлини, Въздушни възглавни...
# 4         200000 км  [Антиблокираща система, Въздушни възглавници -...
# ..              ...                                                ...
# 147       297655 км                                                NaN
# 148       189300 км  [GPS система за проследяване, Автоматичен конт...
# 149       234000 км  [GPS система за проследяване, Автоматичен конт...
# 150       325000 км                       [Парктроник, Система ISOFIX]
# 151       243000 км  [Адаптивни предни светлини, Антиблокираща сист...
#
#                                                  Други  \
# 0        [Напълно обслужен, Нов внос, Сервизна книжка]
# 1                    [Напълно обслужен, С регистрация]
# 2    [Лизинг, Напълно обслужен, Нов внос, С регистр...
# 3                         [Напълно обслужен, Нов внос]
# 4                          [Нов внос, Сервизна книжка]
# ..                                                 ...
# 147                                                NaN
# 148  [4x4, Buy back, Бартер, Лизинг, Нов внос, С ре...
# 149  [4x4, Бартер, Къса база, Лизинг, Напълно обслу...
# 150             [4x4, Напълно обслужен, С регистрация]
# 151                       [4x4, Лизинг, С регистрация]
#
#                                              Екстериор  \
# 0    [4(5) Врати, LED фарове, Лети джанти, Металик,...
# 1    [4(5) Врати, Ксенонови фарове, Лети джанти, Ме...
# 2    [4(5) Врати, LED фарове, Ксенонови фарове, Лет...
# 3    [4(5) Врати, LED фарове, Ксенонови фарове, Лет...
# 4    [4(5) Врати, LED фарове, Ксенонови фарове, Лет...
# ..                                                 ...
# 147                                                NaN
# 148  [4(5) Врати, LED фарове, Лети джанти, Металик,...
# 149  [4(5) Врати, LED фарове, Лети джанти, Металик,...
# 150  [4(5) Врати, LED фарове, Ксенонови фарове, Лет...
# 151                 [4(5) Врати, Лети джанти, Металик]
#
#                                     Защита  \
# 0           [Аларма, Централно заключване]
# 1    [Аларма, Каско, Централно заключване]
# 2    [Аларма, Каско, Централно заключване]
# 3    [Аларма, Каско, Централно заключване]
# 4           [Аларма, Централно заключване]
# ..                                     ...
# 147                                    NaN
# 148         [Аларма, Централно заключване]
# 149  [Аларма, Каско, Централно заключване]
# 150                 [Централно заключване]
# 151                                    NaN
#
#                                                Комфорт       Интериор
# 0    [Auto Start Stop function, Bluetooth \ handsfr...            NaN
# 1    [Auto Start Stop function, Bluetooth \ handsfr...  [Кожен салон]
# 2    [Auto Start Stop function, Bluetooth \ handsfr...  [Кожен салон]
# 3    [Auto Start Stop function, Bluetooth \ handsfr...            NaN
# 4    [Auto Start Stop function, Bluetooth \ handsfr...            NaN
# ..                                                 ...            ...
# 147                                                NaN            NaN
# 148  [Auto Start Stop function, Bluetooth \ handsfr...            NaN
# 149  [Bluetooth \ handsfree система, DVD, TV, Stept...  [Кожен салон]
# 150  [Steptronic, Tiptronic, USB, audio\video, IN\A...  [Кожен салон]
# 151  [Auto Start Stop function, DVD, TV, Steptronic...  [Кожен салон]
#
# [152 rows x 29 columns]

# %%
for label in all_info_labels:
    df_copy=df.dropna(subset=[f"{label}Tech",f"{label}Info"])
    if (df_copy[f"{label}Tech"]!=df_copy[f"{label}Info"]).sum():
        print(label)

# %%
df.columns
# Out:
# Index(['CarModel', 'CarDescription', 'CarPrice', 'Params', 'URL', 'Location',
#        'Status', 'Дата на производствоTech', 'ДвигателTech', 'МощностTech',
#        'ЕвростандартTech', 'Кубатура [куб.см]', 'Скоростна кутияTech',
#        'Категория', 'Пробег [км]Tech', 'Цвят', 'VIN номер',
#        'Дата на производствоInfo', 'ДвигателInfo', 'МощностInfo',
#        'ЕвростандартInfo', 'Скоростна кутияInfo', 'Пробег [км]Info',
#        'Безопасност', 'Други', 'Екстериор', 'Защита', 'Комфорт', 'Интериор'],
#       dtype='object')

# %%
#df.to_csv('out_more.csv')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
